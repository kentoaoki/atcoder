# %% [markdown]
# # Pythonで理解する統計解析の基礎

# %%
# 1章

# %%
import pandas as pd
df = pd.read_csv('../atcoder/data/ch1_sport_test.csv', index_col='生徒番号')
df
# Out:
#       学年    握力  上体起こし  点数  順位
# 生徒番号
# 1      1  40.2     34  15   4
# 2      1  34.2     14   7  10
# 3      1  28.8     27  11   7
# 4      2  39.0     27  14   5
# 5      2  50.9     32  17   2
# 6      2  36.5     20   9   9
# 7      3  36.6     31  13   6
# 8      3  49.2     37  18   1
# 9      3  26.0     28  10   8
# 10     3  47.4     32  16   3

# %%
df['握力']
# Out:
# 生徒番号
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 握力, dtype: float64

# %%
df.shape
# Out:
# (10, 5)

# %%
# ２章

# %%
import numpy as np
import pandas as pd
# %precision 3
pd.set_option('precision', 3)

# %%
df = pd.read_csv('../atcoder/data/ch2_scores_em.csv', index_col='生徒番号')
df.head()
# Out:
#       英語  数学
# 生徒番号
# 1     42  65
# 2     69  80
# 3     56  63
# 4     41  63
# 5     57  76

# %%
scores = np.array(df['英語'])[:10]
scores
# Out:
# array([42, 69, 56, 41, 57, 48, 65, 49, 65, 58])

# %%
scores_df = pd.DataFrame({'点数':scores},
                        index = pd.Index(['A','B','C','D','E','F','G','H','I','J']))
scores_df
# Out:
#    点数
# A  42
# B  69
# C  56
# D  41
# E  57
# F  48
# G  65
# H  49
# I  65
# J  58

# %%
sum(scores)/len(scores)
# Out:
# 55.0

# %%
np.mean(scores)
# Out:
# 55.0

# %%
sorted_scores = np.sort(scores)
sorted_scores
# Out:
# array([41, 42, 48, 49, 56, 57, 58, 65, 65, 69])

# %%
np.median(scores)
# Out:
# 56.5

# %%
scores_mean = np.mean(scores)
scores_dv = scores - scores_mean
scores_dv
# Out:
# array([-13.,  14.,   1., -14.,   2.,  -7.,  10.,  -6.,  10.,   3.])

# %%
summary_df = scores_df.copy()
summary_df['偏差'] = scores_dv
summary_df
# Out:
#    点数    偏差
# A  42 -13.0
# B  69  14.0
# C  56   1.0
# D  41 -14.0
# E  57   2.0
# F  48  -7.0
# G  65  10.0
# H  49  -6.0
# I  65  10.0
# J  58   3.0

# %%
np.mean(scores_dv**2)
# Out:
# 86.0

# %%
summary_df['偏差二乗'] = np.square(scores_dv)
summary_df
# Out:
#    点数    偏差   偏差二乗
# A  42 -13.0  169.0
# B  69  14.0  196.0
# C  56   1.0    1.0
# D  41 -14.0  196.0
# E  57   2.0    4.0
# F  48  -7.0   49.0
# G  65  10.0  100.0
# H  49  -6.0   36.0
# I  65  10.0  100.0
# J  58   3.0    9.0

# %%
scores_Q1=np.percentile(scores,25)
scores_Q1
# Out:
# 48.25

# %%
z = (scores - np.mean(scores))/np.std(scores)
z
# Out:
# array([-1.402,  1.51 ,  0.108, -1.51 ,  0.216, -0.755,  1.078, -0.647,
#         1.078,  0.323])

# %%
np.mean(z),np.std(z)
# Out:
# (-1.6653345369377347e-17, 0.9999999999999999)

# %%
z = 50 + 10*(scores - np.mean(scores))/np.std(scores)
z
# Out:
# array([35.982, 65.097, 51.078, 34.903, 52.157, 42.452, 60.783, 43.53 ,
#        60.783, 53.235])

# %%
scores_df['偏差値'] = z
scores_df
# Out:
#    点数     偏差値
# A  42  35.982
# B  69  65.097
# C  56  51.078
# D  41  34.903
# E  57  52.157
# F  48  42.452
# G  65  60.783
# H  49  43.530
# I  65  60.783
# J  58  53.235
